# %% [markdown]
# <img src="../assets/socalo-ICDA.png">

# %% [markdown]
# # Python para Finazas y Ciencia de Datos

# %% [markdown]
# # Tarea
# <img src="https://files.realpython.com/media/python-basics-wide2.f73a9e9bf9b8.jpg"/>

# %% [markdown]
# ##### Formato de entrega
# * Crear una nueva Jupyter Notebook implementando las funcionalidades requeridas.
# * Guardar la jupyter notebook con el siguiente formato de nombre:
# ```
#             tarea_clase7_NombreApellido.ipynb
#     EJEMPLO:tarea_clase7_FedericoBrun.ipynb
# ```
#
# * Enviar Jupyter Notebook por mail.

# %% [markdown]
# ### Consigna parte 1
#
# A partir del archivo CSV `bancos.csv`, armar un dataframe y aplicar las funciones de las librerias de visualizacion requeridas.
#
# ##### Requisitos minimos parte 1
#
# 1. Armar un DataFrame con el archivo CSV `bancos.csv`.
# 2. Llamar la funcion plot de Pandas para ver qué grafica.
# 3. Reemplazar el indice del Dataframe por la columna Date.
# 4. Volver a graficar con la funcion plot de Pandas
# 5. Usando funciones de MatplotLib, graficar la serie de tiempos de GGAL.
# 6. Usando funciones de Plotly, graficar la serie de tiempos de BMA
# 7. Usando la funcion plot de Pandas, graficar la serie de tiempo de SUPV.
#
# ##### Requisitos minimos parte 2
#
# Para mejorar la atencion al cliente y la experiencia de homebanking, nos encargaron agregar nuevas funcionalidades al sistema que desarrollamos anteriormente.
# Nos pidieron que agreguemos una serie de reportes gráficos para que el cliente pueda llevar un mejor control de sus gastos.
#
# 1. Usando alguna de las estructuras de datos vistas en el curso, llevar un registro del saldo de la caja de ahorro del cliente mes a mes.
# 2. Con la estructura de datos anterior, mostrar un gráfico adecuado al cliente, para que pueda visualizar la evolucion del saldo de su caja de ahorro.
# 3. Construir un diccionario con los gastos del mes del cliente donde la clave será el `concepto` y el valor será el `monto` que el cliente gasto en el mes en ese concepto, ejemplo:
# ```
# gastos_mes = {
#     'impuestos': 6000,
#     'seguro': 2500,
#     'alquiler': 12000
# }
# ```
# con un minimo de 6 categorías (investigar las apps que monitorean gastos, y ver como agrupan los mismos, ejemplo Uala, Brubank, Naranja X, Monefy, etc) y construir un gráfico de torta mostrando la informacion del diccionario.
# 4. Armar otra estructura de datos con alguna de las vistas en el crso, para llevar un registro de los depositos realizados por el cliente y graficarlos con un histograma.
#
# ##### Requisitos extra
# 1. Buscar ejemlos de visualizacion de datos online, y tratar de descubrir si usan alguna de las herramientas mencionadas (Plotly, Dash, Matplotlib).
# 2. Proponer algun objetivo propio en el que podrian mejorar la calidad de su trabajo utilizando alguna visualizacion de las aprendidas.

# %% [markdown]
# Requisitos minimos parte 1¶
#
#     Armar un DataFrame con el archivo CSV bancos.csv.
#     Llamar la funcion plot de Pandas para ver qué grafica.
#     Reemplazar el indice del Dataframe por la columna Date.
#     Volver a graficar con la funcion plot de Pandas
#     Usando funciones de MatplotLib, graficar la serie de tiempos de GGAL.
#     Usando funciones de Plotly, graficar la serie de tiempos de BMA
#     Usando la funcion plot de Pandas, graficar la serie de tiempo de SUPV.

# %%
import pandas as pd

df = pd.read_csv('bancos.csv')
df
# Out:
#             Date  GGAL USD  BMA USD  SUPV USD
# 0     2016-05-19     26.20    60.00     11.50
# 1     2016-05-20     27.10    60.56     11.50
# 2     2016-05-23     26.98    61.90     11.20
# 3     2016-05-24     26.86    60.18     11.52
# 4     2016-05-25     26.84    60.01     11.39
# ...          ...       ...      ...       ...
# 1107  2020-10-12      7.00    13.82      1.68
# 1108  2020-10-13      6.79    13.41      1.66
# 1109  2020-10-14      6.61    13.26      1.61
# 1110  2020-10-15      6.56    13.24      1.60
# 1111  2020-10-16      6.76    13.54      1.68
#
# [1112 rows x 4 columns]

# %%
df.plot()

# %%
df.set_index('Date', inplace=False)

# %%
df.plot()

# %%
import matplotlib.pyplot as plt

# %%
ggal_df = df['GGAL USD']
ggal_df
# Out:
# Date
# 2016-05-19    26.20
# 2016-05-20    27.10
# 2016-05-23    26.98
# 2016-05-24    26.86
# 2016-05-25    26.84
#               ...
# 2020-10-12     7.00
# 2020-10-13     6.79
# 2020-10-14     6.61
# 2020-10-15     6.56
# 2020-10-16     6.76
# Name: GGAL USD, Length: 1112, dtype: float64

# %%
plt.figure(figsize=(15,8))
plt.plot(ggal_df.index, ggal_df )
plt.show();

# %%
df
# Out:
#             GGAL USD  BMA USD  SUPV USD
# Date
# 2016-05-19     26.20    60.00     11.50
# 2016-05-20     27.10    60.56     11.50
# 2016-05-23     26.98    61.90     11.20
# 2016-05-24     26.86    60.18     11.52
# 2016-05-25     26.84    60.01     11.39
# ...              ...      ...       ...
# 2020-10-12      7.00    13.82      1.68
# 2020-10-13      6.79    13.41      1.66
# 2020-10-14      6.61    13.26      1.61
# 2020-10-15      6.56    13.24      1.60
# 2020-10-16      6.76    13.54      1.68
#
# [1112 rows x 3 columns]

# %%
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.figure_factory as ff

# %%
fig = px.line(df, x=df.index, y=df['BMA USD'])
fig.show()
# Out:
# <div>                            <div id="475ec1d3-4e8b-4a11-885c-cc728fba896b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("475ec1d3-4e8b-4a11-885c-cc728fba896b")) {                    Plotly.newPlot(                        "475ec1d3-4e8b-4a11-885c-cc728fba896b",                        [{"hovertemplate": "Date=%{x}<br>BMA USD=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scattergl", "x": ["2016-05-19", "2016-05-20", "2016-05-23", "2016-05-24", "2016-05-25", "2016-05-26", "2016-05-27", "2016-05-31", "2016-06-01", "2016-06-02", "2016-06-03", "2016-06-06", "2016-06-07", "2016-06-08", "2016-06-09", "2016-06-10", "2016-06-13", "2016-06-14", "2016-06-15", "2016-06-16", "2016-06-17", "2016-06-20", "2016-06-21", "2016-06-22", "2016-06-23", "2016-06-24", "2016-06-27", "2016-06-28", "2016-06-29", "2016-06-30", "2016-07-01", "2016-07-05", "2016-07-06", "2016-07-07", "2016-07-08", "2016-07-11", "2016-07-12", "2016-07-13", "2016-07-14", "2016-07-15", "2016-07-18", "2016-07-19", "2016-07-20", "2016-07-21", "2016-07-22", "2016-07-25", "2016-07-26", "2016-07-27", "2016-07-28", "2016-07-29", "2016-08-01", "2016-08-02", "2016-08-03", "2016-08-04", "2016-08-05", "2016-08-08", "2016-08-09", "2016-08-10", "2016-08-11", "2016-08-12", "2016-08-15", "2016-08-16", "2016-08-17", "2016-08-18", "2016-08-19", "2016-08-22", "2016-08-23", "2016-08-24", "2016-08-25", "2016-08-26", "2016-08-29", "2016-08-30", "2016-08-31", "2016-09-01", "2016-09-02", "2016-09-06", "2016-09-07", "2016-09-08", "2016-09-09", "2016-09-12", "2016-09-13", "2016-09-14", "2016-09-