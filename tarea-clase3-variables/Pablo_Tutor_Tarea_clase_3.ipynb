# %%
customer_name = "Francisco"
customer_lastname = "Rey"
customer_mail = "franciscorey@hotmail.com"
customer_id = 20124335
customer_data = (customer_name, customer_lastname, customer_id)
initial_balance = 10000
cards_number = 2
customer_products = "caja de ahorro, cuenta corriente, tarjeta de crédito, tarjeta de débito, plazo fijo, cuenta comitente"
print(customer_data)
# Out:
# ('Francisco', 'Rey', 20124335)

# %%
print("Saldo inicial:\$" + str(initial_balance))
# Out:
# Saldo inicial:\$10000

# %%
expense_insurance = 2000 # se crea una variable que se refiere a un gasto de seguros.
print(initial_balance - expense_insurance)
# Out:
# 8000

# %%
print("Se realizó un gasto por \$" + str(expense_insurance))
# Out:
# Se realizó un gasto por \$2000

# %%
print("Estimado cliente su saldo actualizado al 19/9/2020 es de $" + str(initial_balance - expense_insurance))
# Out:
# Estimado cliente su saldo actualizado al 19/9/2020 es de $8000

# %%
initial_balance = 10000 
expense_insurance= 2000
balance = initial_balance - expense_insurance # se otorgará el préstamo a los clientes que tengan saldo positivo.
if (balance <= 0):
    print("Estimado cliente usted no está autorizado para solicitar un préstamo")
else:
    print("Felicitaciones! Solicitud de préstamo aprobada")
# Out:
# Felicitaciones! Solicitud de préstamo aprobada

# %% [markdown]
# En los primeros puntos se definieron las variables correspondientes a los datos personales del clientes, luego se definieron las variables correspondientes a los datos de la cuenta del cliente y también se especificaron las variables para llegar al saldo del cliente.

# %% [markdown]
# Finalmente se creó una variable para validar el otorgamiento de un préstamo al cliente

# %% [markdown]
# ![286751-mejores-apps-calculadora-cientifica-android-ios.png](attachment:286751-mejores-apps-calculadora-cientifica-android-ios.png)
