# %% [markdown]
# #### Definición de las variables referidas a los datos personales, y asignación de valores
#
# Pasos 1 al 5
# Paso 9

# %%
#Datos personales del cliente
client_name = 'Klaus'
client_last_name = 'Hargreeves'
client_email = 'klaus@umbrella.com'
client_id = '789456123'

data_collection = (client_name, client_last_name, client_email)

print (data_collection)
# Out:
# ('Klaus', 'Hargreeves', 'klaus@umbrella.com')

# %% [markdown]
# #### Definición de las variables referidas a los productos
#
# Pasos 7 y 8

# %%
#Datos de productos
active_cards = 3

client_products = ["caja de ahorro", "cuenta corriente", "tarjeta de credito", "tarjeta de debito", "plazo fijo", "cuenta comitente"]

print ("Saldo inicial: $", initial_balance)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f41f694c3578> in <module>
#       4 client_products = ["caja de ahorro", "cuenta corriente", "tarjeta de credito", "tarjeta de debito", "plazo fijo", "cuenta comitente"]
#       5
# ----> 6 print ("Saldo inicial: $", initial_balance)
#
# NameError: name 'initial_balance' is not defined

# %% [markdown]
# #### Definición de las variables referidas a saldos y movimientos de cuenta
#
# Paso 6
# Pasos 10 al 15
#
# Bonus extra con if!

# %%
# Saldos y movimientos
initial_balance = 0.00
client_expense = 34.59

current_balance = initial_balance - client_expense

print ( "Se realizó un gasto por $", client_expense)

print ( "Su saldo actual es $", current_balance)

if current_balance < 0:
    print ("Saldo negativo!! :(")
elif current_balance > 0:
    print("Aún tiene dinero para gastar! :)")
else:
  print("No tiene dinero en su cuenta")

loan_available = True
print ("Cliente habilitado para proporcionar préstamo?", bool (loan_available))
# Out:
# Se realizó un gasto por $ 34.59
# Su saldo actual es $ -34.59
# Saldo negativo!! :(
# Cliente habilitado para proporcionar préstamo? True

# %% [markdown]
# #### Imagen
# ![pylady_geek.png](attachment:pylady_geek.png)
