# %% [markdown]
# # PABLO TUTOR

# %% [markdown]
# Soy Trader de Futuros y trabajo para una empresa que se llama Gardel Trading:somos Market Makers de Dólar Futuro en Rofex.

# %% [markdown]
# Mi expectativa es en primera instancia aprender una herramienta que me permita analizar datos en forma ágil.

# %% [markdown]
# La finalidad es poder implementar ideas de trading, y en segunda instancia ser capaz de diseñar sistemas de trading.

# %% [markdown]
# ![Chicago-Financial-District-LaSalle-Canyon_700.jpg](attachment:Chicago-Financial-District-LaSalle-Canyon_700.jpg)
