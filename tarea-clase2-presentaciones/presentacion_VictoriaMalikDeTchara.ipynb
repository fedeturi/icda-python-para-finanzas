# %% [markdown]
# # Victoria Malik de Tchara

# %% [markdown]
# ## Hola!
#
# Mi nombre es **Victoria**, soy Ingeniera y actualmente trabajo en una empresa de desarrollo de software, bajo el rol de Product Analyst
#
#
#
# #### Mi vida personal!
# - Madrugadora nata
# - Disfruto practicar yoga y hacer gimnasia
# - Amo las sierras, y estar tirada panza al sol escuchando el ruidito del río
# - Aprendí a jugar al FIFA y Fortnite gracias a mis pequeños adorables demonios, les paso una foto de mi día a día!

# %% [markdown]
# ![WFH.jpg](attachment:WFH.jpg)

# %%
my_nickname = "Vic"

# %%
what_I_hear_most = "Maaaaaaaaaaaaa"

# %%
dogs_amount = "3"

# %%
dogs_name = "Austin, Tasha y Budina"

# %%
print("="*50)
print("Hola! me dicen " + my_nickname + " Pero lo que más escucho es " + what_I_hear_most)
print ("Tengo " + dogs_amount + " perros que se llaman " + dogs_name )
print("="*20)
# Out:
# ...
# Hola! me dicen Vic Pero lo que más escucho es Maaaaaaaaaaaaa
# Tengo 3 perros que se llaman Austin, Tasha y Budina
# ...
