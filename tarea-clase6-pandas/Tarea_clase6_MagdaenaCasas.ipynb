# %%
clientes=[{'nombre':"Maria Magdalena Casas", 'dni':36354348, 'mail':"maguicasas33@gmail.com"},
            {'nombre':"Maria Angelica Casas", 'dni':35483574, 'mail':"aquicasas@hotmail.com"},
            {'nombre':"Solange Wirth", 'dni':25638475, 'mail':"solyw@gmail.com"},
            {'nombre':"Ana Maria Villegas", 'dni':16506384, 'mail':"a.villegas@yahoo.com.ar"},
            {'nombre': "Jorge Zinny", 'dni':10741982, 'mail':"zinny.j@gmail.com"},
            {'nombre':"Carlos Carranza", 'dni':36211983, 'mail':"cacho92@gmail.com"}]

# %%
clientes[2]['nombre']
# Out:
# 'Solange Wirth'

# %%
for cliente in clientes:
    print("su nombre es:" + cliente['nombre']," y su dni es" " "+ str(cliente['dni']))
# Out:
# su nombre es:Maria Magdalena Casas  y su dni es 36354348
# su nombre es:Maria Angelica Casas  y su dni es 35483574
# su nombre es:Solange Wirth  y su dni es 25638475
# su nombre es:Ana Maria Villegas  y su dni es 16506384
# su nombre es:Jorge Zinny  y su dni es 10741982
# su nombre es:Carlos Carranza  y su dni es 36211983

# %%
for cliente in clientes:
    print("su nombre es:" + cliente['nombre']," y su mail es"" "+ cliente['mail'])
# Out:
# su nombre es:Maria Magdalena Casas  y su mail es maguicasas33@gmail.com
# su nombre es:Maria Angelica Casas  y su mail es aquicasas@hotmail.com
# su nombre es:Solange Wirth  y su mail es solyw@gmail.com
# su nombre es:Ana Maria Villegas  y su mail es a.villegas@yahoo.com.ar
# su nombre es:Jorge Zinny  y su mail es zinny.j@gmail.com
# su nombre es:Carlos Carranza  y su mail es cacho92@gmail.com

# %% [markdown]
# ### Consigna 1

# %%
premios= {
    1 :"Viaje a Europa all inclusive por 1 mes",
    2: "Orden de compra por $100000",
    3: "Una semana en un hotel en Bariloche",
    4: "Un celular ",
    5: "Orden de compra por 10000 ",
    6: "una bicicleta"
}

# %%
premios[5]
# Out:
# 'Orden de compra por 10000 '

# %%
for clave in premios:
    print(premios[clave])
# Out:
# Viaje a Europa all inclusive por 1 mes
# Orden de compra por $100000
# Una semana en un hotel en Bariloche
# Un celular
# Orden de compra por 10000
# una bicicleta

# %%
import random
numero_premio = random.randint(1, 6)
print("Numero del premio: ", numero_premio)
# Out:
# Numero del premio:  3

# %%
for premio in premios:
    if premio == numero_premio:
        print("Felicitaiones " + clientes[0]['nombre'])
              
        print("Tu premio es: "+ premios[numero_premio])
              
        break
# Out:
# Felicitaiones Maria Magdalena Casas
# Tu premio es: Una semana en un hotel en Bariloche

# %%
numero_premio = random.randint(1, 6)
print("Numero del premio: ", numero_premio)
# Out:
# Numero del premio:  2

# %%
for premio in premios:
    
    if premio != numero_premio:
        pass
    
    else:
        print("Felicitaiones " + clientes[2]['nombre'])
        print("Tu premio es: " + premios[numero_premio])
# Out:
# Felicitaiones Solange Wirth
# Tu premio es: Orden de compra por $100000

# %% [markdown]
# # Consigna parte 2

# %%
import pandas as pd

# %%
clientes= {'Nombre':["Maria Magdalena", "Maria Angelica", "Solange","Ana Maria","Jorge","Carlos","Luisa", "Guillermo", "Santiago ", "Rosario", "Lucia", "Lucrecia", "Francisco ", "Marcia ", "Luis","Karla"],
          'Apellido':["Casas","Casas","Wirth","Villegas","Zinny","Carranza", "Zinny", "Lozada", "Moyano", "Garcia","Becerra", "Guerra", "Aliaga", "Reyna","Galleto", "Gonzalez"],
          'Dni':[36354348, 35483574, 25638475, 16506384, 10741982, 36211983, 17385909, 17523684, 36985214, 39785236, 28965412, 35216843, 36521638, 36251364, 23156987,  36587362],
          'Sexo':["Mujer","Mujer", "Mujer","Mujer", "Varon", "Varon","Mujer","Varon", "Varon","Mujer", "Mujer", "Mujer","Varon","Mujer","Varon","Mujer"],
          'Mail':["maguicasas33@gmail.com","aquicasas@hotmail.com","solyw@gmail.com","a.villegas@yahoo.com.ar","zinny.j@gmail.com","cacho92@gmail.com","luisazinny@gmail.com","glozada@hotmail.com","s.moyano@gmail.com","rogarcia@gmail.com","lb@gmail.com","lucre_guerra@gmail.com","fa_88@gmail.com","mar.reyna@gmail.com","galleto@gmail.com","kar_gonzalez@gmail.com"],
          'Fecha de Nacimiento':["21/5/92", "05/10/90","21/02/80", "1/07/60", "24/05/64", "21/07,92","19/06/65", "28/02/62","25/03/88", "6/04/99", "22/09/90", "18/03/82", "05/02/80","28/01/92", "30/09/60", "14/05/92"],
          'Sucursal Asignada':["Suc.1", "Suc.2", "Suc.3","Suc.4", "Suc.2", "Suc.5", "Suc.1", "Suc.2", "Suc.3","Suc.4", "Suc.2", "Suc.5","Suc.2", "Suc.5", "Suc.1", "Suc.2"],
          'Lugar de Nacimiento':["Cordoba, Argentina","Cordoba, Argentina","Buenos Aires, Argentina","Montevideo, Uruguay","Cordoba, Argentina","Cordoba, Argentina","Cordoba, Argentina","Cordoba, Argentina","Cordoba, Argentina","Cordoba, Argentina","Cordoba, Argentina","Cordoba, Argentina","Cordoba, Argentina","Cordoba, Argentina","Cordoba, Argentina","Cordoba, Argentina"],
          'Estado Civil':["Soltera", "Soltera", "Casada", "Casada","Casado", "Soltero", "Casada","Casado","Casado", "Soltero", "Casada","Casado","Casado", "Soltero","Casado", "Soltero"],
         'Color favorito':["Azul","Negro", "Amarillo", "Naranja","Verde","Rojo", "Blanco", "Morado", "Gris","Celeste","Amarillo", "Naranja","Verde","Azul","Blanco", "Verde" ]}

# %%
clientes=pd.DataFrame(clientes)

# %%
clientes
# Out:
#              Nombre  Apellido       Dni   Sexo                     Mail  \
# 0   Maria Magdalena     Casas  36354348  Mujer   maguicasas33@gmail.com
# 1    Maria Angelica     Casas  35483574  Mujer    aquicasas@hotmail.com
# 2           Solange     Wirth  25638475  Mujer          solyw@gmail.com
# 3         Ana Maria  Villegas  16506384  Mujer  a.villegas@yahoo.com.ar
# 4             Jorge     Zinny  10741982  Varon        zinny.j@gmail.com
# 5            Carlos  Carranza  36211983  Varon        cacho92@gmail.com
# 6             Luisa     Zinny  17385909  Mujer     luisazinny@gmail.com
# 7         Guillermo    Lozada  17523684  Varon      glozada@hotmail.com
# 8         Santiago     Moyano  36985214  Varon       s.moyano@gmail.com
# 9           Rosario    Garcia  39785236  Mujer       rogarcia@gmail.com
# 10            Lucia   Becerra  28965412  Mujer             lb@gmail.com
# 11         Lucrecia    Guerra  35216843  Mujer   lucre_guerra@gmail.com
# ...

# %%
clientes.index=pd.RangeIndex(1,17)

# %%
clientes
# Out:
#              Nombre  Apellido       Dni   Sexo                     Mail  \
# 1   Maria Magdalena     Casas  36354348  Mujer   maguicasas33@gmail.com
# 2    Maria Angelica     Casas  35483574  Mujer    aquicasas@hotmail.com
# 3           Solange     Wirth  25638475  Mujer          solyw@gmail.com
# 4         Ana Maria  Villegas  16506384  Mujer  a.villegas@yahoo.com.ar
# 5             Jorge     Zinny  10741982  Varon        zinny.j@gmail.com
# 6            Carlos  Carranza  36211983  Varon        cacho92@gmail.com
# 7             Luisa     Zinny  17385909  Mujer     luisazinny@gmail.com
# 8         Guillermo    Lozada  17523684  Varon      glozada@hotmail.com
# 9         Santiago     Moyano  36985214  Varon       s.moyano@gmail.com
# 10          Rosario    Garcia  39785236  Mujer       rogarcia@gmail.com
# 11            Lucia   Becerra  28965412  Mujer             lb@gmail.com
# 12         Lucrecia    Guerra  35216843  Mujer   lucre_guerra@gmail.com
# ...

# %%
clientes.head(3)
# Out:
#             Nombre Apellido       Dni   Sexo                    Mail  \
# 1  Maria Magdalena    Casas  36354348  Mujer  maguicasas33@gmail.com
# 2   Maria Angelica    Casas  35483574  Mujer   aquicasas@hotmail.com
# 3          Solange    Wirth  25638475  Mujer         solyw@gmail.com
#
#   Fecha de Nacimiento Sucursal Asignada      Lugar de Nacimiento Estado Civil  \
# 1             21/5/92             Suc.1       Cordoba, Argentina      Soltera
# 2            05/10/90             Suc.2       Cordoba, Argentina      Soltera
# 3            21/02/80             Suc.3  Buenos Aires, Argentina       Casada
#
#   Color favorito
# 1           Azul
# 2          Negro
# 3       Amarillo

# %%
clientes.tail(3)
# Out:
#      Nombre  Apellido       Dni   Sexo                    Mail  \
# 14  Marcia      Reyna  36251364  Mujer     mar.reyna@gmail.com
# 15     Luis   Galleto  23156987  Varon       galleto@gmail.com
# 16    Karla  Gonzalez  36587362  Mujer  kar_gonzalez@gmail.com
#
#    Fecha de Nacimiento Sucursal Asignada Lugar de Nacimiento Estado Civil  \
# 14            28/01/92             Suc.5  Cordoba, Argentina      Soltero
# 15            30/09/60             Suc.1  Cordoba, Argentina       Casado
# 16            14/05/92             Suc.2  Cordoba, Argentina      Soltero
#
#    Color favorito
# 14           Azul
# 15         Blanco
# 16          Verde

# %%
clientes.dtypes
# Out:
# Nombre                 object
# Apellido               object
# Dni                     int64
# Sexo                   object
# Mail                   object
# Fecha de Nacimiento    object
# Sucursal Asignada      object
# Lugar de Nacimiento    object
# Estado Civil           object
# Color favorito         object
# dtype: object

# %%
clientes.to_excel('datos-clientes-raw.xlsx')

# %%
clientes_df = pd.read_excel('datos-clientes-raw.xlsx')

# %%
clientes_df
# Out:
#     Unnamed: 0           Nombre  Apellido       Dni   Sexo  \
# 0            1  Maria Magdalena     Casas  36354348  Mujer
# 1            2   Maria Angelica     Casas  35483574  Mujer
# 2            3          Solange     Wirth  25638475  Mujer
# 3            4        Ana Maria  Villegas  16506384  Mujer
# 4            5            Jorge     Zinny  10741982  Varon
# 5            6           Carlos  Carranza  36211983  Varon
# 6            7            Luisa     Zinny  17385909  Mujer
# 7            8        Guillermo    Lozada  17523684  Varon
# 8            9        Santiago     Moyano  36985214  Varon
# 9           10          Rosario    Garcia  39785236  Mujer
# 10          11            Lucia   Becerra  28965412  Mujer
# 11          12         Lucrecia    Guerra  35216843  Mujer
# 12          13       Francisco     Aliaga  36521638  Varon
# 13          14          Marcia      Reyna  36251364  Mujer
# 14          15             Luis   Galleto  23156987  Varon
# ...

# %%
columnas_orig=clientes_df.columns
columnas_orig
# Out:
# Index(['Unnamed: 0', 'Nombre', 'Apellido', 'Dni', 'Sexo', 'Mail',
#        'Fecha de Nacimiento', 'Sucursal Asignada', 'Lugar de Nacimiento',
#        'Estado Civil', 'Color favorito'],
#       dtype='object')

# %%
clientes_sucursales_df = clientes_df.drop(['Unnamed: 0', 'Sexo','Fecha de Nacimiento', 'Lugar de Nacimiento','Estado Civil', 'Color favorito'], axis=1)

# %%
clientes_sucursales_df
# Out:
#              Nombre  Apellido       Dni                     Mail  \
# 0   Maria Magdalena     Casas  36354348   maguicasas33@gmail.com
# 1    Maria Angelica     Casas  35483574    aquicasas@hotmail.com
# 2           Solange     Wirth  25638475          solyw@gmail.com
# 3         Ana Maria  Villegas  16506384  a.villegas@yahoo.com.ar
# 4             Jorge     Zinny  10741982        zinny.j@gmail.com
# 5            Carlos  Carranza  36211983        cacho92@gmail.com
# 6             Luisa     Zinny  17385909     luisazinny@gmail.com
# 7         Guillermo    Lozada  17523684      glozada@hotmail.com
# 8         Santiago     Moyano  36985214       s.moyano@gmail.com
# 9           Rosario    Garcia  39785236       rogarcia@gmail.com
# 10            Lucia   Becerra  28965412             lb@gmail.com
# 11         Lucrecia    Guerra  35216843   lucre_guerra@gmail.com
# 12       Francisco     Aliaga  36521638          fa_88@gmail.com
# ...

# %%
clientes_sucursales_df.columns=['Name', 'Surname', 'ID', 'mail adress', 'Branch Office']
clientes_sucursales_df
# Out:
#                Name   Surname        ID              mail adress Branch Office
# 0   Maria Magdalena     Casas  36354348   maguicasas33@gmail.com         Suc.1
# 1    Maria Angelica     Casas  35483574    aquicasas@hotmail.com         Suc.2
# 2           Solange     Wirth  25638475          solyw@gmail.com         Suc.3
# 3         Ana Maria  Villegas  16506384  a.villegas@yahoo.com.ar         Suc.4
# 4             Jorge     Zinny  10741982        zinny.j@gmail.com         Suc.2
# 5            Carlos  Carranza  36211983        cacho92@gmail.com         Suc.5
# 6             Luisa     Zinny  17385909     luisazinny@gmail.com         Suc.1
# 7         Guillermo    Lozada  17523684      glozada@hotmail.com         Suc.2
# 8         Santiago     Moyano  36985214       s.moyano@gmail.com         Suc.3
# 9           Rosario    Garcia  39785236       rogarcia@gmail.com         Suc.4
# 10            Lucia   Becerra  28965412             lb@gmail.com         Suc.2
# ...

# %%
clientes_sucursales_df['message'] = "Estimado/a " + clientes_sucursales_df['Name'] + ": Queremos informarle que la sucursal " + clientes_sucursales_df['Branch Office'] + ", está adecuando sus protocolos para satisfacer las disposiciones del COE Provincial."

# %%
clientes_sucursales_df
# Out:
#                Name   Surname        ID              mail adress  \
# 0   Maria Magdalena     Casas  36354348   maguicasas33@gmail.com
# 1    Maria Angelica     Casas  35483574    aquicasas@hotmail.com
# 2           Solange     Wirth  25638475          solyw@gmail.com
# 3         Ana Maria  Villegas  16506384  a.villegas@yahoo.com.ar
# 4             Jorge     Zinny  10741982        zinny.j@gmail.com
# 5            Carlos  Carranza  36211983        cacho92@gmail.com
# 6             Luisa     Zinny  17385909     luisazinny@gmail.com
# 7         Guillermo    Lozada  17523684      glozada@hotmail.com
# 8         Santiago     Moyano  36985214       s.moyano@gmail.com
# 9           Rosario    Garcia  39785236       rogarcia@gmail.com
# 10            Lucia   Becerra  28965412             lb@gmail.com
# 11         Lucrecia    Guerra  35216843   lucre_guerra@gmail.com
# 12       Francisco     Aliaga  36521638          fa_88@gmail.com
# ...

# %%
clientes_mail = clientes_sucursales_df['mail adress']
clientes_mail
# Out:
# 0      maguicasas33@gmail.com
# 1       aquicasas@hotmail.com
# 2             solyw@gmail.com
# 3     a.villegas@yahoo.com.ar
# 4           zinny.j@gmail.com
# 5           cacho92@gmail.com
# 6        luisazinny@gmail.com
# 7         glozada@hotmail.com
# 8          s.moyano@gmail.com
# 9          rogarcia@gmail.com
# 10               lb@gmail.com
# 11     lucre_guerra@gmail.com
# 12            fa_88@gmail.com
# 13        mar.reyna@gmail.com
# 14          galleto@gmail.com
# 15     kar_gonzalez@gmail.com
# Name: mail adress, dtype: object

# %%
clientes_mail.to_excel('lista-mails-protocolo.xlsx')

# %%
transacciones_df = pd.read_csv('registro.csv')

# %%
transacciones_df
# Out:
#                                    Cuenta;Nro Operacion;Monto;Estado
# 205-418842/5;8136;$35                              458.00;en proceso
# 205-418842/5;9600;$9                                 811.86;aprobada
# 205-418842/5;5005;$8                                 934.30;aprobada
# 205-418842/5;9533;$938.89;aprobada                               NaN
# 205-418842/5;4614;$763.59;aprobada                               NaN
# 205-418842/5;5315;$1                                 534.35;aprobada
# 205-418842/5;9200;$710.41;aprobada                               NaN
# 205-418842/5;2921;$1                                 128.49;aprobada
# 205-418842/5;5112;$24                              048.00;en proceso
# 205-418842/5;6630;$1                                 940.81;aprobada
# 205-418842/5;7140;$7                                 655.50;aprobada
# 205-418842/5;3300;$11                              219.94;en proceso
# 205-418842/5;7126;$12                                048.00;aprobada
# ...

# %%
transacciones_df = pd.read_excel('registro.xlsx')

# %%
transacciones_df
# Out:
#           Cuenta  Nro Operacion       Monto      Estado
# 0   205-418842/5           8136  $35,458.00  en proceso
# 1   205-418842/5           9600   $9,811.86    aprobada
# 2   205-418842/5           5005   $8,934.30    aprobada
# 3   205-418842/5           9533     $938.89    aprobada
# 4   205-418842/5           4614     $763.59    aprobada
# 5   205-418842/5           5315   $1,534.35    aprobada
# 6   205-418842/5           9200     $710.41    aprobada
# 7   205-418842/5           2921   $1,128.49    aprobada
# 8   205-418842/5           5112  $24,048.00  en proceso
# 9   205-418842/5           6630   $1,940.81    aprobada
# 10  205-418842/5           7140   $7,655.50    aprobada
# 11  205-418842/5           3300  $11,219.94  en proceso
# 12  205-418842/5           7126  $12,048.00    aprobada
# 13  205-418842/5           4218   $4,630.29    aprobada
# 14  205-418842/5           8614  $16,028.50  en proceso
# 15  205-418842/5           2912     $763.80    aprobada
# ...

# %%
transacciones_df.sort_values(by='Monto', ascending=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-62542641951f> in <module>
# ----> 1 transacciones_df.sort_values(by='Monto', ascending=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index)
#    4930                 ascending = ascending[0]
#    4931
# -> 4932             indexer = nargsort(
#    4933                 k, kind=kind, ascending=ascending, na_position=na_position
#    4934             )
#
# ~\anaconda3\lib\site-packages\pandas\core\sorting.py in nargsort(items, kind, ascending, na_position)
#     272         non_nans = non_nans[::-1]
#     273         non_nan_idx = non_nan_idx[::-1]
# --> 274     indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     275     if not ascending:
#     276         indexer = indexer[::-1]
#
# ...

# %%
by_monto = transacciones_df.sort_values(float('Monto'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-9895cf7f6582> in <module>
# ----> 1 by_monto = transacciones_df.sort_values(float('Monto'))
#
# ValueError: could not convert string to float: 'Monto'
